# %%
import pandas as pd
import numpy as np
data=pd.read_csv("testdata.csv")

# %%
data.head()
# Out:
#    CorpusId  Audio  BookStatsId  \
# 0         1    NaN           40
# 1         2    NaN           40
# 2         3    NaN           40
# 3         4    NaN           40
# 4        75    NaN           40
#
#                                                CText  Chapt  Verse  \
# 0  nyo koruapu ma igbiki mi oki se ini duko ini p...     28     15
# 1  ọḅụḍuko oyighọrịapụ fịnjị ma Galili chịngị mi ...     28     16
# 2  Ini ori ori siki ini kpereki o tekeme, inia bi...     28     17
# 3  jizọs Be kpekima mun se nwose ini ḅẹme “Ini Ku...     28     18
# 4  Min Jizos Kraist be pakabo furo mi simeoku-e, ...      1      1
#
#                                                PText  ReadersId  UText  \
# 0  nyọ koruapụ ma igbiki mị ọkị se ini ḍuko ini p...          1    NaN
# 1  ọḅụḍuko oyighọrịapụ fịnjị ma Galili chịngị mi ...          1    NaN
# 2  Ini ori ọrị sịkị ini kpẹrẹkị ọ tẹkẹmẹ inia ḅie...          1    NaN
# 3  jizọs ḅe kpekima mun se nwọse ini ḅẹmẹ “Ini kụ...          1    NaN
# 4  mịn jizọs kraịst ḅe pakaḅo furo mị simeọkụ-ẹ D...          1    NaN
#
#               Image            Image2  Verified
# 0  matt28_15-20.PNG               NaN       NaN
# 1  matt28_15-20.PNG               NaN       NaN
# 2  matt28_15-20.PNG               NaN       NaN
# 3  matt28_15-20.PNG               NaN       NaN
# 4  matt01_01-03.png  matt01_03-21.png       0.0

# %%
src = data["CText"].copy()
dst = data["PText"].copy()

# %%
src.head()
# Out:
# 0    nyo koruapu ma igbiki mi oki se ini duko ini p...
# 1    ọḅụḍuko oyighọrịapụ fịnjị ma Galili chịngị mi ...
# 2    Ini ori ori siki ini kpereki o tekeme, inia bi...
# 3    jizọs Be kpekima mun se nwose ini ḅẹme “Ini Ku...
# 4    Min Jizos Kraist be pakabo furo mi simeoku-e, ...
# Name: CText, dtype: object

# %% [markdown]
# Let's remove punctuation symbols
# Punctuation Rules in English
# 1. the period (or full stop in British English)
# 2. the comma.
# 3. the exclamation mark.
# 4. the question mark.
# 5. the colon.
# 6. the semicolon.
# 7. the quotation mark.
# 8. the apostrophe.

# %%
src1=[txt.lower().replace(".","").replace(",","").replace("ẹ","e")
      .replace("!","").replace("?","").replace("“","").replace("ḍ","d")
      .replace(":","").replace(";","").replace("ị","i").replace("ḅ","b")
      .replace("'","").replace("”","").replace("ọ","o")
      .replace("'","").replace("”","").replace("ụ","u")
      .replace('"',"") for txt in src]

# %%
dst1=[txt.lower().replace(".","").replace(",","")
      .replace("!","").replace("?","").replace("“","")
      .replace(":","").replace(";","")
      .replace("'","").replace("”","")
      .replace('"',"") for txt in dst]

# %%
len(dst1)==len(src1)
# Out:
# True

# %%
[len(src1[i].split())==len(dst1[i].split()) for i in range(len(src1))]
# Out:
# [True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
[(len(src1[i].split()),len(dst1[i].split())) for i in range(len(src1))]
# Out:
# [(40, 40),
#  (16, 16),
#  (16, 16),
#  (19, 18),
#  (22, 22),
#  (20, 18),
#  (25, 25),
#  (15, 15),
#  (21, 21),
#  (18, 18),
#  (15, 15),
#  (15, 15),
#  (15, 15),
#  (15, 15),
#  (21, 21),
#  (19, 19),
#  (15, 15),
#  (15, 15),
#  (15, 15),
#  (18, 18),
#  (50, 50),
#  (37, 37),
#  (24, 24),
#  (42, 42),
#  (19, 19),
#  (34, 34),
#  (34, 34),
#  (24, 24),
#  (22, 22),
#  (15, 15),
#  (29, 29),
#  (28, 28),
#  (32, 32),
#  (38, 38),
#  (15, 15),
#  (21, 21),
#  (19, 19),
#  (28, 28),
#  (21, 21),
#  (43, 41),
#  (30, 30),
#  (53, 53),
#  (18, 18),
#  (45, 45),
#  (63, 63),
#  (14, 13),
#  (34, 34),
#  (16, 16),
#  (41, 41),
#  (16, 16),
#  (43, 43),
#  (39, 39),
#  (18, 18),
#  (15, 15),
#  (31, 31),
#  (27, 27),
#  (21, 19),
#  (14, 14),
#  (36, 36),
#  (12, 12),
#  (37, 37),
#  (27, 27),
#  (41, 41),
#  (40, 40),
#  (20, 18),
#  (28, 28),
#  (32, 32),
#  (39, 39),
#  (21, 21),
#  (15, 15),
#  (16, 16)]

# %%
f=[len(src1[i].split())==len(dst1[i].split()) for i in range(len(src1))]

# %%
len(f)
# Out:
# 71

# %%
src=[i for indx,i in enumerate(src1) if f[indx] == True]
dst=[i for indx,i in enumerate(dst1) if f[indx] == True]
src0=[i for indx,i in enumerate(src1) if f[indx] == False]
dst0=[i for indx,i in enumerate(dst1) if f[indx] == False]

# %%
ds=pd.DataFrame({'src':src, 'dst':dst})
ds
# Out:
#                                                   dst  \
# 0   nyọ koruapụ ma igbiki mị ọkị se ini ḍuko ini p...
# 1   ọḅụḍuko oyighọrịapụ fịnjị ma galili chịngị mi ...
# 2   ini ori ọrị sịkị ini kpẹrẹkị ọ tẹkẹmẹ inia ḅie...
# 3   mịn jizọs kraịst ḅe pakaḅo furo mị simeọkụ-ẹ d...
# 4   juda ḅe pẹrẹz ḅe na zẹra ḅe na yimẹ (inia nyen...
# 5   ram ḅe amịnadab ḅe yimẹ amịnadab ḅe nasọn ḅe y...
# 6   salmọn ḅe boaz bẹ yimẹ (rehab ma nyọngọrọ-ẹ) b...
# 7   jẹsi ḅe amanyana devid ḅe ḅe yimẹ devid ḅe sol...
# 8   solomọn ḅe rẹhobuam ḅe yimẹ rẹhobuam ḅe abaịja...
# 9   asa ḅe jehosịafat ḅe yimẹ jehosịafat ḅe joram ...
# 10  ozaya ḅe jotam ḅe yimẹ jotam ḅe ehaz ḅe yimẹ e...
# 11  hẹzịkaya ḅe manasị ḅe yimẹ manasị ḅe amọn ḅe y...
# 26  o tibini agbamieapu ma na oloko dieapu mamgba ...
# 27  ini nwo pekereme betlihem ama judia se mi bie ...
# 28  betlihem judia se mi bie iri ngisi bokateinke ...
# 29  ani herod be boima iruapakapaka nyo bu weri bo...
# ..                                                ...
# 35  josef be mono bu sise siki nyanabo be enjelbo ...
# 36  okuma ori ari na gbolomake okimun aria tari ow...
# 37  tamuno be dawo bu weri inia berijineme na ini ...
# 38  ini so boro siki nyanabo be enjelbo obu se daw...
# 39  josef be sise se toku be na nyongoro ma na dek...
# 40  anianga o sime mun herod be fi siki nwo lame m...
# 41  herod be bo nemi na irua pakapaka nyo bu weri ...
# 42  rema bie ini owutibi bie naame aku owu be nyo ...
# 43  herod be fi boro siki nyanabo be enjelbo dawoj...
# 44  se nwo beme sise se toku be na nyongoro ma na ...
# 45  ani josef be sise se toku be na nyongoro ma na...
# 46  josef be bo naa na akilos be dawu herod amanya...
# 47  se mun nazaret nwo chin ama mi se oria anga ny...
# 48  anisiki mi bu jon mengisarabo be judia onwu el...
# 49  o nwo beme omine ominea si ma bu vinpiki aniat...
# 50  aizaya ikiankorobo be jon be bu bere dukoari s...
# 51  ikeasun namaichuka ini nwose buchuaye mie jon ...
# 52  ini inia sima duko pakumame se o jodan mi bie ...
# 53  jon be ion-a farisiapu na sadusiapu na mengisa...
# 54  ominea si ma bu o barasinsam nwo be ye o nwo m...
# 55  se o koroma ma na omine ineda igani mi bu mang...
# 56  apala mi ini ani karakaramasam kunoma bu weri ...
# 57  a mengi seni o sarame se diepakuma na o sibupi...
# 58  oria yesele ogu ori na omi-e o se ipiamgba mag...
# 59  okuma jon be bukuroma dokime jizos be o kubie ...
# 60  okuma jizos be nwose o pekereme ye ani pa miok...
# 61  o mengi mi se jizos be sara so kirikiri jizos ...
# 62  ani puko sobie nwo be ye-e be ani ibu yela tok...
# 63  anisiki teme be jizos be nwo boroma onwuele og...
# 64  jizos be buru o tarime enekaka-a mesi na din-a...
#
# [65 rows x 2 columns]

# %%
x=[];y=[]
[x.extend(i) for i in dst]
[y.extend(i) for i in src]
cy=set(x)
cx=set(y)
print(len(cx),len(cy))
cx2ix = { ch:i for i,ch in enumerate(cx) }
ix2cx = { i:ch for i,ch in enumerate(cx) }
cy2ix = { ch:i for i,ch in enumerate(cy) }
ix2cy = { i:ch for i,ch in enumerate(cy) }
cyi=np.array([i for i,_ in enumerate(cy)])
cyi=np.append(cyi,[-1],axis=0)
# Out:
# 30 42

# %%
X=[]
for x in src:
    X.extend(x.split())
Y=[]
[Y.extend(x.split()) for x in dst]
print(len(X),len(Y))
# Out:
# 1715 1715

# %%
import numpy as np

inpX = [list(data) for data in X]
iX=[]
for data in inpX:
    subl=[]
    for ch in data:
        subl.append(cx2ix[ch])
    iX.append(subl)
len(iX)
#iX=np.array(iX)
# Out:
# 1715

# %%
tgtY=[list(data) for data in Y]
tY=[]
#tY=[cy2ix[ch] for subl in tgtY for ch in data]
for data in tgtY:
    subl=[]
    for ch in data:
        subl.append(cy2ix[ch])
    tY.append(subl)
#tY=np.array(tY)

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
sx=[len(x) for x in iX]
sy=[len(x) for x in tY]

def seqpad(seq,seql):
    arr=[]
    m=max(seql)
    for i in seq:
        n=m-len(i)
        for j in range(n):
            i.append(-1)
        arr.append(i)
    return arr

def seqpad2(seq,m):
    arr=[]
    for i in seq:
        n=m-len(i)
        for j in range(n):
            i.append(-1)
        arr.append(i)
    return arr

iX=np.array(seqpad2(iX,50))
tY=np.array(seqpad2(tY,50))
iX
# Out:
# array([[21, 20,  3, ..., -1, -1, -1],
#        [10,  3, 16, ..., -1, -1, -1],
#        [23, 19, -1, ..., -1, -1, -1],
#        ...,
#        [ 3, 13,  9, ..., -1, -1, -1],
#        [17, 27, 23, ..., -1, -1, -1],
#        [ 9,  2, -1, ..., -1, -1, -1]])

# %%
import tensorflow as tf
reset_graph()

n_steps = 50
n_neurons = 200
n_layers = 3
num_encoder_symbols = len(cx) #20000
num_decoder_symbols = len(cy) #20000
embedding_size = 1
learning_rate = 0.01

X = tf.placeholder(tf.int32, [None, n_steps]) # English sentences
Y = tf.placeholder(tf.int32, [None, n_steps]) # French translations
y = tf.placeholder(tf.int32,[None])
W = tf.placeholder(tf.float32, [None, n_steps - 1, 1])

Y_input = Y[:, :-1]
Y_target = Y[:, 1:]

encoder_inputs = tf.unstack(tf.transpose(X)) # list of 1D tensors
decoder_inputs = tf.unstack(tf.transpose(Y_input)) # list of 1D tensors

lstm_cells = [tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)
              for layer in range(n_layers)]
cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)

output_seqs, states = tf.contrib.legacy_seq2seq.embedding_rnn_seq2seq(
#output_seqs, states = tf.contrib.legacy_seq2seq.basic_rnn_seq2seq(
    # X, 
    encoder_inputs,
    # Y_input, 
    decoder_inputs,
    cell,
    num_encoder_symbols,num_decoder_symbols,embedding_size
    )

logits = tf.transpose(tf.unstack(output_seqs), perm=[1, 0, 2])

# %%
logits_flat = tf.reshape(logits, [-1, num_decoder_symbols])

#logits_flat = tf.layers.dense(states,num_decoder_symbols)
Y_target_flat = tf.reshape(Y_target, [-1])
W_flat = tf.reshape(W, [-1])
xentropy = W_flat * tf.nn.sparse_softmax_cross_entropy_with_logits(labels=Y_target_flat, logits=logits_flat)
loss = tf.reduce_mean(xentropy)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)

correct = tf.nn.in_top_k(logits_flat, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()

# %%
n_epochs = 100
batch_size = 150
w = np.ones( (len(iX), n_steps - 1, 1), dtype=np.float32 )
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        #for iteration in range(mnist.train.num_examples // batch_size):
        #    X_batch, y_batch = mnist.train.next_batch(batch_size)
        #    X_batch = X_batch.reshape((-1, n_steps, n_inputs))
        sess.run(training_op, feed_dict={X: iX, Y: tY, y:cyi, W:w})
        acc_train = accuracy.eval(feed_dict={X: iX, Y: tY, y:cyi, W:w})
        acc_test = accuracy.eval(feed_dict={X: iX, Y: tY, y:cyi, W:w})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#
# ~/anaconda3_501/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: indices[0] = -1 is not in [0, 30)
# 	 [[Node: embedding_rnn_seq2seq/rnn/embedding_wrapper_8/embedding_lookup = Gather[Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@embedding_rnn_seq2seq/rnn/embedding_wrapper/embedding/read"], validate_indices=true, _device="/job:localhost/replica:0/task:0/cpu:0"](embedding_rnn_seq2seq/rnn/embedding_wrapper/embedding/read, embedding_rnn_seq2seq/rnn/embedding_wrapper_8/Reshape)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-356-82f36d5a526f> in <module>()
#       8         #    X_batch, y_batch = mnist.train.next_batch(batch_size)
#       9         #    X_batch = X_batch.reshape((-1, n_steps, n_inputs))
# ---> 10         sess.run(training_op, feed_dict={X: iX, Y: tY, y:cyi, W:w})
#      11         acc_train = accuracy.eval(feed_dict={X: iX, Y: tY, y:cyi, W:w})
#      12         acc_test = accuracy.eval(feed_dict={X: iX, Y: tY, y:cyi, W:w})
#
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1050         except KeyError:
#    1051           pass
# -> 1052       raise type(e)(node_def, op, message)
#    1053
#    1054   def _extend_graph(self):
#
# InvalidArgumentError: indices[0] = -1 is not in [0, 30)
# 	 [[Node: embedding_rnn_seq2seq/rnn/embedding_wrapper_8/embedding_lookup = Gather[Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@embedding_rnn_seq2seq/rnn/embedding_wrapper/embedding/read"], validate_indices=true, _device="/job:localhost/replica:0/task:0/cpu:0"](embedding_rnn_seq2seq/rnn/embedding_wrapper/embedding/read, embedding_rnn_seq2seq/rnn/embedding_wrapper_8/Reshape)]]
#
# Caused by op 'embedding_rnn_seq2seq/rnn/embedding_wrapper_8/embedding_lookup', defined at:
#   File "/home/nbuser/anaconda3_501/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 281, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 232, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 397, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-354-f6fe0cadb60f>", line 34, in <module>
#     num_encoder_symbols,num_decoder_symbols,embedding_size
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/contrib/legacy_seq2seq/python/ops/seq2seq.py", line 364, in embedding_rnn_seq2seq
#     encoder_cell, encoder_inputs, dtype=dtype)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/contrib/rnn/python/ops/core_rnn.py", line 197, in static_rnn
#     (output, state) = call_cell()
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/contrib/rnn/python/ops/core_rnn.py", line 184, in <lambda>
#     call_cell = lambda: cell(input_, state)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/contrib/rnn/python/ops/core_rnn_cell_impl.py", line 880, in __call__
#     embedding, array_ops.reshape(inputs, [-1]))
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/ops/embedding_ops.py", line 119, in embedding_lookup
#     params[0], ids, validate_indices=validate_indices, name=name))
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/ops/embedding_ops.py", line 41, in _do_gather
#     params, ids, name=name, validate_indices=validate_indices)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py", line 1207, in gather
#     validate_indices=validate_indices, name=name)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 768, in apply_op
#     op_def=op_def)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2336, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/nbuser/anaconda3_501/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1228, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): indices[0] = -1 is not in [0, 30)
# 	 [[Node: embedding_rnn_seq2seq/rnn/embedding_wrapper_8/embedding_lookup = Gather[Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@embedding_rnn_seq2seq/rnn/embedding_wrapper/embedding/read"], validate_indices=true, _device="/job:localhost/replica:0/task:0/cpu:0"](embedding_rnn_seq2seq/rnn/embedding_wrapper/embedding/read, embedding_rnn_seq2seq/rnn/embedding_wrapper_8/Reshape)]]

# %%
len(cx)
# Out:
# 30
